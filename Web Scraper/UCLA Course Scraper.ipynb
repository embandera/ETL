# %%
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <base/>
#   <title>
#    Search Results
#   </title>
#   <link href="/ro/iwe/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="/ro/iwe/css/bundle/IweCssAll.css" rel="stylesheet"/>
#   <link href="/ro/bundles/SOCCSS?v=R668_rHfv7nspxRfqfIPFIfc3ORxe67DpX7oQNQikbU1" rel="stylesheet">
#    <script src="/ro/bundles/iwejsAll?v=i-NmexwXdCgfA6FKoI-EXtG0p1Guaq-yCeAEvEOrEBI1">
#    </script>
#    <meta content="UCLA Registrar’s Office website offers information and resources for current students, prospective students, faculty and staff, and alumni. It is home to the quarterly Schedule of Classes, the General Catalog, important dates and deadlines, fee information, and more." id="MetaDescription" name="DESCRIPTION">
# ...

# %%
class_name=[] # List where class names are stored
# create a loop that runs through all <div> elements
for row in soup.find_all('div', attrs={'class':'row-fluid class-title'}):
    class_name.append(row.text.strip('\n '))
print(class_name)
# Out:
# ['1 - Freshman Computer Science Seminar', "19 - From Impossible to I'm Possible: Analysis of Impostor Phenomenon", '30 - Principles and Practices of Computing', '31 - Introduction to Computer Science I', '33 - Introduction to Computer Organization', '35L - Software Construction Laboratory', 'M51A - Logic Design of Digital Systems', '111 - Operating Systems Principles', '118 - Computer Network Fundamentals', 'CM121 - Introduction to Bioinformatics', '130 - Software Engineering', '131 - Programming Languages', '132 - Compiler Construction', '136 - Introduction to Computer Security', '143 - Database Systems', '145 - Introduction to Data Mining', 'M146 - Introduction to Machine Learning', 'M151B - Computer Systems Architecture', 'M152A - Introductory Digital Design Laboratory', '152B - Digital Design Project Laboratory', '161 - Fundamentals of Artificial Intelligence', '174A - Introduction to Computer Graphics', '180 - Introduction to Algorithms and Complexity', '181 - Introduction to Fo
# ...

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", chrome_options=options)
# Out:
# /Users/mitzibandera/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: use options instead of chrome_options
#   import sys
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# ...

# %%
class_time_start=[] # List where class names are stored
# create a loop that runs through all <div> elements
for row in soup.find_all('div', attrs={'class':'row-fluid class-title'}):
    class_name.append(row.text.strip('\n '))
print(class_name)
# Out:
# []

# %%
VALID_TAGS = ['div', 'p']

# soup = BeautifulSoup(value)

for tag in soup.findAll('p'):
    if tag.name not in VALID_TAGS:
        tag.replaceWith(tag.renderContents())

print(soup.renderContents())
# Out:
# b'\n<!DOCTYPE html>\n\n<html lang="en">\n<head>\n<meta charset="utf-8"/>\n<base/>\n<title>Search Results</title>\n<link href="/ro/iwe/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>\n<meta content="width=device-width" name="viewport"/>\n<meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>\n<link href="/ro/iwe/css/bundle/IweCssAll.css" rel="stylesheet"/>\n<link href="/ro/bundles/SOCCSS?v=R668_rHfv7nspxRfqfIPFIfc3ORxe67DpX7oQNQikbU1" rel="stylesheet">\n<script src="/ro/bundles/iwejsAll?v=i-NmexwXdCgfA6FKoI-EXtG0p1Guaq-yCeAEvEOrEBI1"></script>\n<meta content="UCLA Registrar\xe2\x80\x99s Office website offers information and resources for current students, prospective students, faculty and staff, and alumni. It is home to the quarterly Schedule of Classes, the General Catalog, important dates and deadlines, fee information, and more." id="MetaDescription" name="DESCRIPTION">\n<meta content="UCLA Registrar\xe2\x80\x99s Office, UCLA RO" id="MetaKeywords" name="KEYWORD
# ...

# %%
# page = soup.findAll('p').getText()

# %%
products_data= pd.DataFrame() # DataFrame with the data on product names and prices
products_data['name'] = name_products
products_data['price'] = price
print(products_data.head(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7943f2a289de> in <module>
#       1 products_data= pd.DataFrame() # DataFrame with the data on product names and prices
# ----> 2 products_data['name'] = name_products
#       3 products_data['price'] = price
#       4 print(products_data.head(5))
#
# NameError: name 'name_products' is not defined
